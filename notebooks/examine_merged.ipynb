# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
processed = '/home/mitch/Dropbox/data/mexico_enigh/processed/'
os.chdir(processed)
df = pd.read_csv('data.csv')
# Out:
# /tmp/ipykernel_136798/3198711041.py:3: DtypeWarning: Columns (71,82,134,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv')

# %%
df
# Out:
#         Unnamed: 0          hhid  location  weight  location_size    INGMON
# 0                0   19940110010      1001   169.0              1   6480.00  \
# 1                1   19940110010      1001   169.0              1   6480.00
# 2                2   19940110010      1001   169.0              1   6480.00
# 3                3   19940110010      1001   169.0              1   6480.00
# 4                4   19940110010      1001   169.0              1   6480.00
# ...            ...           ...       ...     ...            ...       ...
# 215909      215909  200032190230     32042  1392.0              4   7568.76
# 215910      215910  200032190230     32042  1392.0              4   7568.76
# 215911      215911  200032190240     32042  1392.0              4  21203.76
# 215912      215912  200032190240     32042  1392.0              4  21203.76
# 215913      215913  200032190240     32042  1392.0              4  21203.76
#
# ...

# %%
df.sort_values(['hhid', 'Y'])
# Out:
#         Unnamed: 0          hhid  location  weight  location_size    INGMON
# 0                0   19940110010      1001   169.0              1   6480.00  \
# 1                1   19940110010      1001   169.0              1   6480.00
# 2                2   19940110010      1001   169.0              1   6480.00
# 3                3   19940110010      1001   169.0              1   6480.00
# 4                4   19940110010      1001   169.0              1   6480.00
# ...            ...           ...       ...     ...            ...       ...
# 215909      215909  200032190230     32042  1392.0              4   7568.76
# 215910      215910  200032190230     32042  1392.0              4   7568.76
# 215911      215911  200032190240     32042  1392.0              4  21203.76
# 215912      215912  200032190240     32042  1392.0              4  21203.76
# 215913      215913  200032190240     32042  1392.0              4  21203.76
#
# ...

# %%
df['weight']
# Out:
# 0          169.0
# 1          169.0
# 2          169.0
# 3          169.0
# 4          169.0
#            ...
# 215909    1392.0
# 215910    1392.0
# 215911    1392.0
# 215912    1392.0
# 215913    1392.0
# Name: weight, Length: 215914, dtype: float64
